# %% [markdown]
# ## pandas
#
# - https://pandas.pydata.org/docs/user_guide/index.html
# - excel 생각하면 됨
# - column - feature
# - row -sample
#
# ![다운로드.png](attachment:bb6a33bb-c498-477e-a287-ed17ad07c5ad.png)
# ___

# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.3'

# %%
sr = pd.Series([3, 2, 3, 4, 7], name='apple') # 한 줄 밖에 없어서 column 이라 안함
sr2 = pd.Series([4, 5, 3, 4, 8], name='banana')
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr2
# Out:
# 0    4
# 1    5
# 2    3
# 3    4
# 4    8
# Name: banana, dtype: int64

# %%
sr3 = pd.Series([4, 5, 3, 4, 8], name='mango', index=['A', 'B', 'C', 'D', 'E'])
sr3
# Out:
# A    4
# B    5
# C    3
# D    4
# E    8
# Name: mango, dtype: int64

# %%
df = pd.concat([sr, sr2], axis = 1)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.concat([sr, sr2, sr3], axis =1)
df
# Out:
#    apple  banana  mango
# 0    3.0     4.0    NaN
# 1    2.0     5.0    NaN
# 2    3.0     3.0    NaN
# 3    4.0     4.0    NaN
# 4    7.0     8.0    NaN
# A    NaN     NaN    4.0
# B    NaN     NaN    5.0
# C    NaN     NaN    3.0
# D    NaN     NaN    4.0
# E    NaN     NaN    8.0

# %%
data = [
    ['John', 'Tom', 'Alice'],
    [3, 4, 5],
    [True, False, True]
]

pd.DataFrame(data)
# Out:
#       0      1      2
# 0  John    Tom  Alice
# 1     3      4      5
# 2  True  False   True

# %%
data = [
    ['John', 5, True],
    ['Tom', 4, False],
    ['Alice', 6, True]
]

pd.DataFrame(data)
# Out:
#        0  1      2
# 0   John  5   True
# 1    Tom  4  False
# 2  Alice  6   True

# %%
data = {
    'name':['John', 'Tom', 'Alice'],
    'point':[3, 5, 4],
    'Pass':[False, True, False]
}

df = pd.DataFrame(data)
df
# Out:
#     name  point   Pass
# 0   John      3  False
# 1    Tom      5   True
# 2  Alice      4  False

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'point', 'Pass'], dtype='object')

# %%
data = {
    'name':['John', 'Tom', 'Alice'],
    'point':[3, 5, 4],
    'Pass':[False, True, False]
}

df_x = pd.DataFrame(data)
df_x.columns = ['Name', 'Point', 'Pass']
df_x
# Out:
#     Name  Point   Pass
# 0   John      3  False
# 1    Tom      5   True
# 2  Alice      4  False

# %%
df_x = df_x.rename(columns={'Point':'Score'})

df_x
# Out:
#     Name  Score   Pass
# 0   John      3  False
# 1    Tom      5   True
# 2  Alice      4  False

# %%
iris = pd.read_csv("./datasets/titanic_train.csv")
iris.shape
# Out:
# (891, 12)

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()  # 상위 5개의 데이터 출력
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
iris.tail()  # 하위 5개의 데이터 출력
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
iris.info()  # 비어있는 데이터 - 결측치 (missing value)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sr4 = iris.isna().sum(axis = 0) # 비어있는 데이터 개수
sr4
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
type(sr4)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

plt.bar(sr4.index, sr4.values)
plt.xticks(rotation=90)
plt.show()

# %%
titanic = iris.copy()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.Embarked.unique()  # column 의 이름이 영어이고, 공백이 없을 때 쓸 수 있지만, 많이 사용하지는 않음
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
type(titanic["Embarked"])
# Out:
# pandas.core.series.Series

# %%
pd.get_dummies(titanic["Embarked"])  # one-hot encoding
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
type(titanic[["Embarked", "Pclass"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic["Embarked"]  # Series
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic[["Embarked"]]  # DataFrame
# Out:
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 1 columns]

# %% [markdown]
# ### slicing 하는 방법
#
# * iloc
# * loc

# %%
titanic.iloc[0:5,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
titanic.loc[(titanic["Embarked"]=='C') & (titanic['Survived']==1) , :]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 31            32         1       1
# 36            37         1       3
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 36                                    Mamee, Mr. Hanna    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[0:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
titanic.sort_index(axis=0, ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(by=["Age"])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.sort_values(by=["Age","Fare"])
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 새로운 column 을 만들면서 데이터를 조작하는 것 == feature engineering

titanic["FamilySize"]=titanic["SibSp"] + titanic["Parch"]
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
titanic.drop(["SibSp","Parch"], axis=1 , inplace=True)  # inplace -> 원본이 바뀜 | 변수에 저장하거나 inplace 사용

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
titanic.loc[titanic["Age"] < 1., "Cabin"] = "None"  # 원본 바뀜
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
titanic.loc[titanic["Cabin"]=="None", :]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  Ticket      Fare Cabin Embarked  FamilySize
# 78   0.83  248738   29.0000  None        S           2
# 305  0.92  113781  151.5500  None        S           3
# 469  0.75    2666   19.2583  None        C           3
# 644  0.75    2666   19.2583  None        C           3
# 755  0.67  250649   14.5000  None        S           2
# ...

# %%
df = titanic.select_dtypes(include=["float64"])  # number - 숫자 타입의 column 을 다 가져오기, float64 - 실수 타입의 column 가져오기
df
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
def f1(x):
    # print(type(x))
    return x.max() - x.min()

# %%
df.apply(f1)
# Out:
# Age      79.5800
# Fare    512.3292
# dtype: float64

# %%
def f2(x):   # Serise 값 (컬럼 전체 값)
    if x > 30:
        return 0
    else:
        return 1

# %%
df["Age"].apply(f2)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 886    1
# 887    1
# 888    1
# 889    1
# 890    0
# Name: Age, Length: 891, dtype: int64

# %%
df["Age2"] = df["Age"].apply(f2)

# %%
df
# Out:
#       Age     Fare  Age2
# 0    22.0   7.2500     1
# 1    38.0  71.2833     0
# 2    26.0   7.9250     1
# 3    35.0  53.1000     0
# 4    35.0   8.0500     0
# ..    ...      ...   ...
# 886  27.0  13.0000     1
# 887  19.0  30.0000     1
# 888   NaN  23.4500     1
# 889  26.0  30.0000     1
# 890  32.0   7.7500     0
#
# [891 rows x 3 columns]

# %%
def f3(x):
    if x == 'male':
        return 1
    else:
        return 0

# %%
titanic.Sex = titanic.Sex.apply(f3)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           1
# 1          PC 17599  71.2833   C85        C           1
# 2  STON/O2. 3101282   7.9250   NaN        S           0
# 3            113803  53.1000  C123        S           1
# 4            373450   8.0500   NaN        S           0

# %%
titanic["Survived"] = titanic["Survived"].apply(lambda x : 'saved' if x == 1 else 'lost')
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     lost       3
# 1            2    saved       1
# 2            3    saved       3
# 3            4    saved       1
# 4            5     lost       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           1
# 1          PC 17599  71.2833   C85        C           1
# 2  STON/O2. 3101282   7.9250   NaN        S           0
# 3            113803  53.1000  C123        S           1
# 4            373450   8.0500   NaN        S           0

# %%
titanic["Survived"]=titanic["Survived"].map({"saved":0, "lost":1})  #  apply 안에 lamda 식으로 쓰기 어려우면 map 사용하기
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           1
# 1          PC 17599  71.2833   C85        C           1
# 2  STON/O2. 3101282   7.9250   NaN        S           0
# 3            113803  53.1000  C123        S           1
# 4            373450   8.0500   NaN        S           0

# %% [markdown]
# ### 결측치 제거

# %%
titanic.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
x = titanic.dropna()
x.shape
# Out:
# (208, 11)

# %%
x = titanic.fillna(0)
x.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
# 5            6         1       3
# 6            7         1       1
# 7            8         1       3
# 8            9         0       3
# 9           10         0       2
#
#                                                 Name  Sex        Age  \
# 0                            Braund, Mr. Owen Harris    1  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000
# 2                             Heikkinen, Miss. Laina    0  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000
# 4                           Allen, Mr. William Henry    1  35.000000
# 5                                   Moran, Mr. James    1  29.699118
# 6                            McCarthy, Mr. Timothy J    1  54.000000
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           1
# 1          PC 17599  71.2833   C85        C           1
# 2  STON/O2. 3101282   7.9250   NaN        S           0
# 3            113803  53.1000  C123        S           1
# 4            373450   8.0500   NaN        S           0

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["Age"] = titanic["Age"].fillna(titanic["Age"].mean())
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Embarked"] = titanic["Embarked"].fillna("S")
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
titanic.drop(["Cabin"],axis=1, inplace = True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       3
# 1              2         0       1
# 2              3         0       3
# 3              4         0       1
# 4              5         1       3
# ..           ...       ...     ...
# 886          887         1       2
# 887          888         0       1
# 888          889         1       3
# 889          890         0       1
# 890          891         1       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    1  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000
# 2                               Heikkinen, Miss. Laina    0  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000
# 4                             Allen, Mr. William Henry    1  35.000000
# ..                                                 ...  ...        ...
# ...

# %%
sr = titanic["Embarked"].value_counts()
sr
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
import matplotlib.pyplot as plt

# sr.index, sr.values

plt.bar(sr.index, sr.values)
plt.title("Embarked")
plt.show()

# %%
# 남성 승객의 나이 평균
man = titanic.loc[titanic["Sex"] == 1, "Age"]
print(man.mean())

# 여성 승객의 나이 평균
woman = titanic.loc[titanic["Sex"] == 0, "Age"]
print(woman.mean())

titanic.groupby('Sex').Age.mean()
# Out:
# 30.505824243042102
# 28.21673004870738
# Sex
# 0    28.216730
# 1    30.505824
# Name: Age, dtype: float64

# %% [markdown]
# ### GroupBy

# %%
data = {
    'city': ['Busan', 'Busan', 'Busan', 'Busan', 'Seoul', 'Seoul', 'Seoul'],
    'fruit': ['Apple', 'Orange', 'Banana', 'Banana', 'Apple', 'Apple', 'Banana'],
    'price': [100, 200, 250, 300, 150, 200, 400],
    'quantity': [1, 2, 3, 4, 5, 6, 7]
}

df = pd.DataFrame(data)
df
# Out:
#     city   fruit  price  quantity
# 0  Busan   Apple    100         1
# 1  Busan  Orange    200         2
# 2  Busan  Banana    250         3
# 3  Busan  Banana    300         4
# 4  Seoul   Apple    150         5
# 5  Seoul   Apple    200         6
# 6  Seoul  Banana    400         7

# %%
df.groupby('city').price.mean()
# Out:
# city
# Busan    212.5
# Seoul    250.0
# Name: price, dtype: float64

# %%
df.groupby(['city', 'fruit']).mean()
# Out:
#               price  quantity
# city  fruit
# Busan Apple   100.0       1.0
#       Banana  275.0       3.5
#       Orange  200.0       2.0
# Seoul Apple   175.0       5.5
#       Banana  400.0       7.0

# %%
titanic.groupby('Sex').Survived.mean()  # 사망률 (생존 = 0 , 사망 = 1)
# Out:
# Sex
# 0    0.257962
# 1    0.811092
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass').Survived.mean()  # 사망률
# Out:
# Pclass
# 1    0.370370
# 2    0.527174
# 3    0.757637
# Name: Survived, dtype: float64

# %% [markdown]
# ### 연속형 데이터 -> 범주형 데이터

# %%
titanic['AgeClass'] = pd.cut(titanic['Age'], 3, labels=['child', 'young', 'old'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Embarked  FamilySize AgeClass
# 0         A/5 21171   7.2500        S           1    child
# 1          PC 17599  71.2833        C           1    young
# 2  STON/O2. 3101282   7.9250        S           0    child
# 3            113803  53.1000        S           1    young
# 4            373450   8.0500        S           0    young

# %%
titanic["AgeClass"].value_counts()
# Out:
# young    522
# child    319
# old       50
# Name: AgeClass, dtype: int64

# %%
titanic = titanic.drop(["Age"], axis=1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name  Sex            Ticket  \
# 0                            Braund, Mr. Owen Harris    1         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0          PC 17599
# 2                             Heikkinen, Miss. Laina    0  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0            113803
# 4                           Allen, Mr. William Henry    1            373450
#
#       Fare Embarked  FamilySize AgeClass
# 0   7.2500        S           1    child
# 1  71.2833        C           1    young
# 2   7.9250        S           0    child
# 3  53.1000        S           1    young
# 4   8.0500        S           0    young

# %% [markdown]
# ### 문자열 처리

# %%
type(titanic["Name"])
# Out:
# pandas.core.series.Series

# %%
import numpy as np

data = {
    "Dave": "dave@gmail.com",
    "Steve": "steve",
    "Rob": "rob@gmail.com",
    "Wes": "wes@hotmail.com"
}
sr = pd.Series(data)
sr
# Out:
# Dave      dave@gmail.com
# Steve              steve
# Rob        rob@gmail.com
# Wes      wes@hotmail.com
# dtype: object

# %%
sr.index
# Out:
# Index(['Dave', 'Steve', 'Rob', 'Wes'], dtype='object')

# %%
sr.str.contains("gmail")
# Out:
# Dave      True
# Steve    False
# Rob       True
# Wes      False
# dtype: bool

# %%
sr.str.findall("gmail")
# Out:
# Dave     [gmail]
# Steve         []
# Rob      [gmail]
# Wes           []
# dtype: object

# %%
sr.str.findall('^[a-zA-Z0-9+-\_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+$')
# Out:
# Dave      [dave@gmail.com]
# Steve                   []
# Rob        [rob@gmail.com]
# Wes      [wes@hotmail.com]
# dtype: object

# %% [markdown]
# ### 시계열 데이터
#
# - 공장 기계 고장 예측 ?
# - 공장 센서 데이터, 주식 데이터 등

# %%
data = np.random.randn(1000, 3)
data.shape
# Out:
# (1000, 3)

# %%
df = pd.DataFrame(data, index=pd.date_range('1/1/2022', periods=1000), columns=['A', 'B', 'C'])  # 원래는 csv file load

# %%
df.head(10)
# Out:
#                    A         B         C
# 2022-01-01 -0.260690 -1.155041 -0.727544
# 2022-01-02 -1.497294  0.108038  1.879394
# 2022-01-03  1.095758 -0.701098 -0.762695
# 2022-01-04 -0.485061  0.676116 -1.907697
# 2022-01-05  1.722936  1.581040  1.100018
# 2022-01-06  0.457008 -0.924929 -0.513631
# 2022-01-07 -0.385536  2.588898  0.371282
# 2022-01-08 -2.283228 -1.972472  1.491096
# 2022-01-09  0.208093 -0.304901  1.656948
# 2022-01-10  1.423863  0.390641  0.207422
